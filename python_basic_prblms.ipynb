# %% [markdown]
# <a href="https://colab.research.google.com/github/sumanu9400/Python_problems/blob/main/python_basic_prblms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# reverce string

original_string = input()
reverce_string=original_string[::-1]
print(reverce_string)
# Out:
# heloo
# ooleh

# %%
s=input()
def is_palindrome_exact(s):
    return s == s[::-1]

print(is_palindrome_exact(s))
# Out:
# 12321
# True

# %%
s=input()
def is_palindrome(s):
    return s == s[::-1]

print(is_palindrome(s))
# Out:
# suman
# False

# %%
n=input()
m=int(input())
n2=n[-m:]+n[:-m]
print(n2)
# Out:
# sumanyanamala
# 3
# alasumanyanam

# %%
n=int(input())

for i in range(1,n+1):
  for j in range(1,n+1):
    print(" "*(n-j)+"* "*j)
# Out:
# 5
#     *
#    * *
#   * * *
#  * * * *
# * * * * *

# %%
n=int(input())
for i in range (n):
  for j in range (i+1):
    print(" *",end=" ")
  print("\n")
# Out:
# 5
#  *
#
#  *  *
#
#  *  *  *
#
#  *  *  *  *
#
#  *  *  *  *  *
